# %% [markdown]
# # Clustering Spotify Songs With K-Means

# %% [markdown]
# ### 1. Connecting to Exasol

# %%
# import packages
import pandas as pd
import pyodbc

# define connection function
def df_from_odbc(dsn, sql_query):
    with pyodbc.connect(f"DSN={dsn}") as conn:
        df_data = pd.read_sql_query(sql_query, conn)
    return df_data

df = df_from_odbc(dsn="Exasol dev", sql_query="select * from LOAD_REFERENCE.SPOTIFY_SONGS")

# %% [markdown]
# ### 2. Data Cleansing and Preparation

# %%
# import main packages
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme(style='whitegrid')

# %%
# inspect the data
df.head()
# Out:
#                  TRACK_ID                                         TRACK_NAME  \
# 0  6f807x0ima9a1j3VPbc7VN  I Don't Care (with Justin Bieber) - Loud Luxur...
# 1  0r7CVbZTWZgbTCYdfa2P31                    Memories - Dillon Francis Remix
# 2  1z1Hg7Vb0AhHDiEmnDE79l                    All the Time - Don Diablo Remix
# 3  75FpbthrwQmzHlBJLuGdC7                  Call You Mine - Keanu Silva Remix
# 4  1e8PAfcKUYoKkxPhrHqw4x            Someone You Loved - Future Humans Remix
#
#        TRACK_ARTIST  TRACK_POPULARITY          TRACK_ALBUM_ID  \
# 0        Ed Sheeran              66.0  2oCs0DGTsRO98Gh5ZSl2Cx
# 1          Maroon 5              67.0  63rPSO264uRjW1X5E6cWv6
# 2      Zara Larsson              70.0  1HoSmj2eLcsrR0vE9gThr4
# 3  The Chainsmokers              60.0  1nqYsOef1yKKuGOVchbsk6
# 4     Lewis Capaldi              69.0  7m7vv9wlQ4i0LFuJiE2zsQ
#
#                                     TRACK_ALBUM_NAME TRACK_ALBUM_RELEASE_DATE  \
# 0  I Don't Care (with Justin Bieber) [Loud Luxury...               14/06/2019
# 1                    Memories (Dillon Francis Remix)               13/12/2019
# 2                    All the Time (Don Diablo Remix)               05/07/2019
# 3                        Call You Mine - The Remixes               19/07/2019
# 4            Someone You Loved (Future Humans Remix)               05/03/2019
#
#   PLAYLIST_NAME             PLAYLIST_ID PLAYLIST_GENRE  ...   KEY  LOUDNESS  \
# 0     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   6.0    -2.634
# 1     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...  11.0    -4.969
# 2     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1.0    -3.432
# 3     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   7.0    -3.778
# 4     Pop Remix  37i9dQZF1DXcZDD7cfEKhW            pop  ...   1.0    -4.672
#
#    MODE  SPEECHINESS  ACOUSTICNESS  INSTRUMENTALNESS  LIVENESS  VALENCE  \
# 0   1.0       0.0583        0.1020          0.000000    0.0653    0.518
# 1   1.0       0.0373        0.0724          0.004210    0.3570    0.693
# 2   0.0       0.0742        0.0794          0.000023    0.1100    0.613
# 3   1.0       0.1020        0.0287          0.000009    0.2040    0.277
# 4   1.0       0.0359        0.0803          0.000000    0.0833    0.725
#
#      TEMPO  DURATION_MS
# 0  122.036     194754.0
# 1   99.972     162600.0
# 2  124.008     176616.0
# 3  121.956     169093.0
# 4  123.976     189052.0
#
# [5 rows x 23 columns]

# %%
# drop columns and duplicates 
df = df.drop(columns = ['PLAYLIST_NAME','PLAYLIST_ID','PLAYLIST_GENRE','PLAYLIST_SUBGENRE']).copy()
df = df.drop_duplicates().copy()

# %%
# check for null values
df.isna().sum().sort_values(ascending=False)
# Out:
# TRACK_ID                    0
# LOUDNESS                    0
# TEMPO                       0
# VALENCE                     0
# LIVENESS                    0
# INSTRUMENTALNESS            0
# ACOUSTICNESS                0
# SPEECHINESS                 0
# MODE                        0
# KEY                         0
# TRACK_NAME                  0
# ENERGY                      0
# DANCEABILITY                0
# TRACK_ALBUM_RELEASE_DATE    0
# TRACK_ALBUM_NAME            0
# TRACK_ALBUM_ID              0
# TRACK_POPULARITY            0
# TRACK_ARTIST                0
# DURATION_MS                 0
# dtype: int64

# %%
# check for duplicate rows 
df.duplicated().any()
# Out:
# False

# %%
# select initial k-means features
features = df[['TRACK_POPULARITY','KEY','LOUDNESS','SPEECHINESS','ACOUSTICNESS','INSTRUMENTALNESS','LIVENESS','VALENCE','TEMPO','DURATION_MS']].copy()
features.head()
# Out:
#    TRACK_POPULARITY   KEY  LOUDNESS  SPEECHINESS  ACOUSTICNESS  \
# 0              66.0   6.0    -2.634       0.0583        0.1020
# 1              67.0  11.0    -4.969       0.0373        0.0724
# 2              70.0   1.0    -3.432       0.0742        0.0794
# 3              60.0   7.0    -3.778       0.1020        0.0287
# 4              69.0   1.0    -4.672       0.0359        0.0803
#
#    INSTRUMENTALNESS  LIVENESS  VALENCE    TEMPO  DURATION_MS
# 0          0.000000    0.0653    0.518  122.036     194754.0
# 1          0.004210    0.3570    0.693   99.972     162600.0
# 2          0.000023    0.1100    0.613  124.008     176616.0
# 3          0.000009    0.2040    0.277  121.956     169093.0
# 4          0.000000    0.0833    0.725  123.976     189052.0

# %% [markdown]
# ### 3. Data Exploration

# %%
features.describe().round(2)
# Out:
#        TRACK_POPULARITY       KEY  LOUDNESS  SPEECHINESS  ACOUSTICNESS  \
# count          28356.00  28356.00  28356.00     28356.00      28356.00
# mean              39.33      5.37     -6.82         0.11          0.18
# std               23.70      3.61      3.04         0.10          0.22
# min                0.00      0.00    -46.45         0.00          0.00
# 25%               21.00      2.00     -8.31         0.04          0.01
# 50%               42.00      6.00     -6.26         0.06          0.08
# 75%               58.00      9.00     -4.71         0.13          0.26
# max              100.00     11.00      1.27         0.92          0.99
#
#        INSTRUMENTALNESS  LIVENESS   VALENCE     TEMPO  DURATION_MS
# count          28356.00  28356.00  28356.00  28356.00     28356.00
# mean               0.09      0.19      0.51    120.96    226575.97
# std                0.23      0.16      0.23     26.95     61078.45
# min                0.00      0.00      0.00      0.00      4000.00
# 25%                0.00      0.09      0.33     99.97    187742.00
# 50%                0.00      0.13      0.51    121.99    216933.00
# 75%                0.01      0.25      0.70    134.00    254975.25
# max                0.99      1.00      0.99    239.44    517810.00

# %% [markdown]
# Here we see there are over 28,000 rows in this dataset. We also see that the variables are not all measured on the same scale.

# %%
# Create boxplots
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(15, 5))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Plot each column
for i, col in enumerate(features):
    sns.boxplot(y=features[col], ax=axes[i], color='lightblue')
    axes[i].set_title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Some variables have a lot of outliers.

# %%
# create histograms
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(15, 5))

# Flatten the axes array for easy iteration
axes = axes.flatten()

# Plot each column
for i, col in enumerate(features):
    sns.histplot(features[col], bins=10, kde=False, ax=axes[i], color='lightblue')
    axes[i].set_title(col)
plt.tight_layout()
plt.show()

# %% [markdown]
# Some variables have a fairly normal distribution.

# %%
# heatmap to check for any relationships
plt.figure(figsize=(12,7))
sns.heatmap(features.corr(),annot=True,)
plt.show()

# %%
# Observe some relationships with scatterplots based on the heatmap above

sns.scatterplot(data = features, x = 'ACOUSTICNESS', y = 'LOUDNESS', color='hotpink')
plt.show()

# %%
sns.scatterplot(data = features, x = 'VALENCE', y = 'INSTRUMENTALNESS', color='hotpink')
plt.show()

# %%
sns.scatterplot(data = features, x = 'DURATION_MS', y = 'TRACK_POPULARITY', color='hotpink')
plt.show()

# %% [markdown]
# Not able to see any obvious clusters or relationships due to the amount of datapoints.

# %% [markdown]
# ### 5. Reducing the Dataset
# Due to the number of rows and the amount of potential features that could be included in the K-means algorithm, the cost/run time of the algorithm could be too high. Therefore, the dataset will be reduced and 2 features will be selected to allow for reduced cost/run time and easier visualisation. I will select variables with few outliers and a fairly normal distribution.

# %%
# reduce the original dataset to include only the top 1000 most popular songs
reduced_dataset = df.sort_values(by=['TRACK_POPULARITY'], ascending=False).head(1000)
reduced_dataset.describe().round(2)
# Out:
#        TRACK_POPULARITY  DANCEABILITY   ENERGY      KEY  LOUDNESS     MODE  \
# count           1000.00       1000.00  1000.00  1000.00   1000.00  1000.00
# mean              80.96          0.68     0.65     5.25     -6.12     0.58
# std                4.34          0.14     0.17     3.68      2.62     0.49
# min               76.00          0.15     0.06     0.00    -23.02     0.00
# 25%               78.00          0.59     0.54     1.00     -7.23     0.00
# 50%               80.00          0.70     0.67     5.00     -5.73     1.00
# 75%               83.00          0.78     0.78     9.00     -4.44     1.00
# max              100.00          0.97     0.99    11.00      0.30     1.00
#
#        SPEECHINESS  ACOUSTICNESS  INSTRUMENTALNESS  LIVENESS  VALENCE  \
# count      1000.00       1000.00           1000.00   1000.00  1000.00
# mean          0.12          0.21              0.01      0.17     0.51
# std           0.11          0.23              0.07      0.13     0.22
# min           0.02          0.00              0.00      0.02     0.04
# 25%           0.04          0.04              0.00      0.09     0.35
# 50%           0.07          0.13              0.00      0.12     0.52
# 75%           0.15          0.31              0.00      0.20     0.69
# max           0.86          0.95              0.81      0.96     0.97
#
#          TEMPO  DURATION_MS
# count  1000.00      1000.00
# mean    121.36    213005.70
# std      29.24     46549.02
# min      48.72    104591.00
# 25%      97.48    182507.50
# 50%     118.88    207039.00
# 75%     140.03    235906.50
# max     205.27    484147.00

# %% [markdown]
# Here we have checked that the dataset has been reduced to 1000 rows.

# %%
# select the new reduced number of features from the original df, this time ensuring we have track id, name, and artist name
new_features = reduced_dataset[['TRACK_ID','TRACK_NAME','TRACK_ARTIST','VALENCE','TEMPO']]
new_features = pd.DataFrame(new_features)
new_features.head()
# Out:
#                      TRACK_ID       TRACK_NAME    TRACK_ARTIST  VALENCE  \
# 1551   2XU0oxnq2qxCpomAAuJY8K     Dance Monkey     Tones and I    0.513
# 17437  696DnlkuDOXcMAnKlTgXXK          ROXANNE  Arizona Zervas    0.457
# 1301   21jGcNKet2qwijlDFuPiPb          Circles     Post Malone    0.553
# 716    0sf12qNH5qcw8qpgymFOqD  Blinding Lights      The Weeknd    0.345
# 687    7k4t7uLgtOxPwTpFmtJNTY             Tusa         KAROL G    0.574
#
#          TEMPO
# 1551    98.027
# 17437  116.735
# 1301   120.042
# 716    171.017
# 687    101.085

# %%
# remove outliers
Q1 = new_features['TEMPO'].quantile(0.25)
Q3 = new_features['TEMPO'].quantile(0.75)
IQR = Q3 - Q1

# Define the lower and upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
features_filtered = new_features[(new_features['TEMPO'] >= lower_bound) & (new_features['TEMPO'] <= upper_bound)].copy()

features_filtered.describe().round(2)
# Out:
#        VALENCE   TEMPO
# count   999.00  999.00
# mean      0.51  121.28
# std       0.22   29.14
# min       0.04   48.72
# 25%       0.35   97.42
# 50%       0.52  118.85
# 75%       0.69  140.02
# max       0.97  197.70

# %%
# examine the relationship
sns.scatterplot(data = new_features, x = 'VALENCE', y = 'TEMPO', color='hotpink')
plt.show()

# %% [markdown]
# ### 6. Standardising the Data

# %% [markdown]
# #### Z-Score Normalisation.

# %%
# scale the data
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler()
data_scaled = scaler.fit_transform(new_features[['VALENCE','TEMPO']].copy())
data_scaled = pd.DataFrame(data_scaled, columns = ['VALENCE','TEMPO'])
data_scaled = pd.concat([data_scaled.copy(), new_features[['TRACK_ID','TRACK_NAME','TRACK_ARTIST']].copy().reset_index(drop=True)], axis=1)
data_scaled.head()
# Out:
#     VALENCE     TEMPO                TRACK_ID       TRACK_NAME    TRACK_ARTIST
# 0 -0.008065 -0.798407  2XU0oxnq2qxCpomAAuJY8K     Dance Monkey     Tones and I
# 1 -0.260115 -0.158388  696DnlkuDOXcMAnKlTgXXK          ROXANNE  Arizona Zervas
# 2  0.171971 -0.045252  21jGcNKet2qwijlDFuPiPb          Circles     Post Malone
# 3 -0.764216  1.698655  0sf12qNH5qcw8qpgymFOqD  Blinding Lights      The Weeknd
# 4  0.266490 -0.693790  7k4t7uLgtOxPwTpFmtJNTY             Tusa         KAROL G

# %%
# check that the scaling worked (mean should be 0, std dv should be 1)
data_scaled.describe().round(2)
# Out:
#        VALENCE    TEMPO
# count  1000.00  1000.00
# mean     -0.00    -0.00
# std       1.00     1.00
# min      -2.14    -2.49
# 25%      -0.76    -0.82
# 50%       0.01    -0.08
# 75%       0.78     0.64
# max       2.04     2.87

# %% [markdown]
# ### 7. Creating Initial Clusters

# %%
# create initial clusters using a random number
from sklearn.cluster import KMeans 
km = KMeans(n_clusters = 10, n_init = 50, random_state = 123)
km.fit(data_scaled[["VALENCE", "TEMPO"]])
# Out:
# KMeans(n_clusters=10, n_init=50, random_state=123)

# %%
# look at the inertia value
km.inertia_
# Out:
# 230.913530927893

# %% [markdown]
# This inertia value is not that close to 0 so perhaps 10 is not the correct number of clusters. I will visually inspect the clusters and explore the correct number of clusters later using the elbow method and the silhouette score.

# %% [markdown]
# ### 6. Evaluating the Clusters

# %%
# check the number of datapoints per cluster
pd.Series(km.labels_).value_counts().sort_index()
# Out:
# 0     42
# 1     77
# 2    129
# 3     82
# 4    111
# 5    130
# 6    146
# 7     92
# 8    125
# 9     66
# dtype: int64

# %% [markdown]
# Some clusters have significantly more datapoints than others, suggesting that 10 might not be enough.

# %% [markdown]
# #### Visually Inspecting the Clusters

# %%
# check the coordinates of the clusters
km.cluster_centers_
# Out:
# array([[-1.24977803,  1.70032911],
#        [ 1.3575793 , -0.9656908 ],
#        [ 0.06335658,  0.138496  ],
#        [ 0.0741042 ,  1.58863298],
#        [ 1.26966451,  0.16929243],
#        [-0.54128319, -0.91683353],
#        [ 0.35518279, -0.91587065],
#        [-1.51482016, -0.76307777],
#        [-1.04689466,  0.45158872],
#        [ 1.23500277,  1.55574333]])

# %%
# convert the array above to a dataframe for easier inspection
cluster_centres = pd.DataFrame(km.cluster_centers_, columns = ['VALENCE','TEMPO'])
cluster_centres
# Out:
#     VALENCE     TEMPO
# 0 -1.249778  1.700329
# 1  1.357579 -0.965691
# 2  0.063357  0.138496
# 3  0.074104  1.588633
# 4  1.269665  0.169292
# 5 -0.541283 -0.916834
# 6  0.355183 -0.915871
# 7 -1.514820 -0.763078
# 8 -1.046895  0.451589
# 9  1.235003  1.555743

# %% [markdown]
# The data has been scaled so the mean is 0. This helps us form a visual of where the clusters might be on a plot.

# %%
# append the new clusters to our dataframe to see which songs are in which cluster
data_scaled["Cluster"] = km.labels_

# %%
data_scaled.head(50)
# Out:
#      VALENCE     TEMPO                TRACK_ID  \
# 0  -0.008065 -0.798407  2XU0oxnq2qxCpomAAuJY8K
# 1  -0.260115 -0.158388  696DnlkuDOXcMAnKlTgXXK
# 2   0.171971 -0.045252  21jGcNKet2qwijlDFuPiPb
# 3  -0.764216  1.698655  0sf12qNH5qcw8qpgymFOqD
# 4   0.266490 -0.693790  7k4t7uLgtOxPwTpFmtJNTY
# 5   0.270991 -1.038158  2b8fOow8UzyDFAE27YhOZM
# 6   0.572552 -0.150314  0nbXyq5TXYPCO7pr3N8S4I
# 7  -1.254815  0.195765  4TnjEaWOeW0eKTKIEvJyCa
# 8   0.730083  0.088137  6WrI0LAC5M1Rw2MnX2ZvEg
# 9  -1.223308 -0.046483  3ZCTVFBt2Brf31RLEnCkWJ
# 10  0.685074 -0.560059  6cy3ki60hLwimwIje7tALf
# 11 -0.089081  0.837359  41L3O37CECZt3N7ziG2z7l
# 12  0.212480  0.470856  2Fxmhks0bxGSBdJ92vM42m
# 13 -2.044723 -1.535929  3eekarcy7kvN4yt5ZFzltW
# 14  1.661770 -0.116890  2tnVG71enUj33Ic2nFN6kZ
# 15 -0.593182 -0.558280  3yOlyBJuViE2YSGn3nVE1K
# 16  0.734584  0.295045  7aiClxsDWFRQ0Kzk5KI5ku
# 17 -0.309625 -0.392528  7qEHsqek33rTcFNT9PFqLf
# 18 -0.030569  0.707220  5yY9lUy8nbvjM1Uyo1Uqoc
# 19 -1.904745 -0.662726  1HfMVBKM75vxSfsQ5VefZ5
# 20  1.445727  0.184920  6Ozh9Ok6h4Oi1wUSLtBseN
# 21  1.058649 -0.151135  0TK2YIli7K1leLovkQiNik
# 22  0.424022 -0.558930  2ksOAxtIxY8yElEWw8RhgK
# 23  0.050447 -1.005418  5DxXgozhkPLgrbKFY91w0c
# 24 -1.425849  1.662289  57vxBYXtHMk6H1aD29V7PU
# 25 -0.008065 -0.798407  5ZULALImTm80tzUbYQYM9d
# 26 -1.335831 -1.281604  285pBltuF7vW8TeWk8hdRR
# 27 -0.404144  2.007718  6Gg1gjgKi2AK4e0qzsR7sd
# 28  1.229684 -0.936038  6mAN61JH0dzyZpWslS11jy
# 29 -0.741712  0.228300  3VyjsVV24RmBIbWJAeUJNu
# 30 -0.084580  0.294464  51Fjme0JiitpyXKuyQiCDo
# 31 -0.984761  0.533873  2Ec33AVlkTTq8BHFgBTdQs
# 32 -0.773218  2.069503  5stPVcRqb4qixbafP9e8lt
# 33  0.243986 -0.763478  1M4qEo4HE3PRaCOM7EXNJq
# 34  0.063950  0.087932  7CHi4DtfK4heMlQaudCuHK
# 35 -0.386141  1.872174  0fea68AdmYNygeTGI4RC18
# 36  0.901118 -0.850887  6LcauUZjF1eXQrgqMUecHX
# 37  0.689575 -0.799810  4vUmTMuQqjdnvlZmAH61Qk
# 38 -0.381640 -1.073327  2wrJq5XKLnmhRXHIAf9xBa
# 39 -0.764216 -0.369401  6b2RcmUt1g9N9mQ3CbjX2Y
# 40 -1.218808  1.874910  2TH65lNHgvLxCKXM3apjxI
# 41 -1.493363 -0.324448  7ce20yLkzuXXLUhzIDoZih
# 42  1.472732 -0.663992  3HVWdVOQ0ZA45FuZGSfvns
# 43  0.725582 -1.142399  7sQKy5vlPQllr0k9IjYJv3
# 44 -0.075578  0.186049  1iQDltZqI7BXnHrFy4Qo1k
# 45  0.559049  0.502090  2YpeDb67231RjR0MgVLzsG
# 46  0.869611 -0.936894  6RyaV7owmVU6fzEPE17sF1
# 47 -0.845233  0.639174  6ocbgoVGwYJhOv1GgI9NsF
# 48 -1.299824  2.005083  1lOe9qE0vR9zwWQAOk6CoO
# 49  0.189975 -0.888622  1e9oZCCiX42nJl0AcqriVo
#
#                                            TRACK_NAME         TRACK_ARTIST  \
# 0                                        Dance Monkey          Tones and I
# 1                                             ROXANNE       Arizona Zervas
# 2                                             Circles          Post Malone
# 3                                     Blinding Lights           The Weeknd
# 4                                                Tusa              KAROL G
# 5                                            Memories             Maroon 5
# 6                                             The Box          Roddy Ricch
# 7                                             Falling        Trevor Daniel
# 8                                     Don't Start Now             Dua Lipa
# 9                                 everything i wanted        Billie Eilish
# 10                          RITMO (Bad Boys For Life)  The Black Eyed Peas
# 11                                              Yummy        Justin Bieber
# 12                                            bad guy        Billie Eilish
# 13                                HIGHEST IN THE ROOM         Travis Scott
# 14                                            Ride It               Regard
# 15                            My Oh My (feat. DaBaby)       Camila Cabello
# 16                                    hot girl bummer            blackbear
# 17                                  Someone You Loved        Lewis Capaldi
# 18                         Life Is Good (feat. Drake)               Future
# 19                                Lose You To Love Me         Selena Gomez
# 20                                                BOP               DaBaby
# 21                                           Señorita         Shawn Mendes
# 22                                              China             Anuel AA
# 23                                               Vete            Bad Bunny
# 24                                          Heartless           The Weeknd
# 25                                       Dance Monkey          Tones and I
# 26                                       Lucid Dreams           Juice WRLD
# 27           Bandit (with YoungBoy Never Broke Again)           Juice WRLD
# 28                                          Fantasias       Rauw Alejandro
# 29                                            No Idea          Don Toliver
# 30                                             Lalala                  Y2K
# 31                                Futsal Shuffle 2020         Lil Uzi Vert
# 32                                       Hola - Remix                Dalex
# 33                                          Adore You         Harry Styles
# 34                                       Lose Control               MEDUZA
# 35                                         LA CANCIÓN             J Balvin
# 36                                       Ayy Macarena                 Tyga
# 37  South of the Border (feat. Camila Cabello & Ca...           Ed Sheeran
# 38                  10,000 Hours (with Justin Bieber)           Dan + Shay
# 39                                  How Do You Sleep?            Sam Smith
# 40                                           Callaita            Bad Bunny
# 41                                      Before You Go        Lewis Capaldi
# 42                  I Don't Care (with Justin Bieber)           Ed Sheeran
# 43                                      Sigues Con El          Dimelo Flow
# 44                             Trampoline (with ZAYN)                SHAED
# 45                              Old Town Road - Remix            Lil Nas X
# 46                                  Que Tire Pa Lante         Daddy Yankee
# 47                                            7 rings        Ariana Grande
# 48                                             Ransom            Lil Tecca
# 49                                   Watermelon Sugar         Harry Styles
#
#     Cluster
# 0         6
# 1         2
# 2         2
# 3         0
# 4         6
# 5         6
# 6         2
# 7         8
# 8         4
# 9         8
# 10        6
# 11        2
# 12        2
# 13        7
# 14        4
# 15        5
# 16        4
# 17        5
# 18        2
# 19        7
# 20        4
# 21        4
# 22        6
# 23        6
# 24        0
# 25        6
# 26        7
# 27        3
# 28        1
# 29        8
# 30        2
# 31        8
# 32        0
# 33        6
# 34        2
# 35        3
# 36        1
# 37        6
# 38        5
# 39        5
# 40        0
# 41        7
# 42        1
# 43        6
# 44        2
# 45        2
# 46        1
# 47        8
# 48        0
# 49        6

# %%
# plotting the clusters and centroids
# set fig size
plt.figure(figsize = (10, 8))

# plot clusters
ax = sns.scatterplot(data = data_scaled,
                    x = 'VALENCE',
                    y = 'TEMPO',
                    hue = 'Cluster',
                    palette = 'pastel',
                    alpha = 0.8,
                    s = 150,
                    legend = False)
# plot centroids
ax = sns.scatterplot(data = cluster_centres,
                    x = 'VALENCE',
                    y = 'TEMPO',
                    hue = cluster_centres.index,
                    palette = 'pastel',
                    s = 600,
                    marker = 'D',
                    ec = 'black',
                    legend = False)

# add centroid labels 
for i in range(len(cluster_centres)):
    plt.text(x = cluster_centres.VALENCE[i],
            y = cluster_centres.TEMPO[i],
            s = i,
            horizontalalignment = 'center',
            verticalalignment = 'center',
            size = 15,
            weight = 'bold',
            color = 'white')

# %% [markdown]
# Earlier inspection suggested that some clusters appeared to be bigger than others, suggesting that these clusters might need evaluating. However, upon inspection, these clusters do not appear to be unusual. They appear to be quite evenly spread, though some have more datapoints than others.

# %% [markdown]
# ### 7. Evaluating the Number of Clusters

# %% [markdown]
# #### Elbow Method

# %%
elbow = []
for k in range(2, 25):
    km = KMeans(n_clusters = k, n_init = 50, random_state=123)
    km.fit(data_scaled[['VALENCE','TEMPO']])
    elbow.append(km.inertia_)

elbow_series = pd.Series(elbow, index = range(2, 25))

plt.figure(figsize=(8,6))
ax = sns.lineplot(y=elbow_series, x=elbow_series.index)
ax = sns.scatterplot(y=elbow_series, x=elbow_series.index, s=150)
ax = ax.set(xlabel = 'Number of Clusters (k)',
           ylabel = 'Within Cluster Sum of Squares')
plt.show()

# %% [markdown]
# There appears to be no clear 'elbow' in the plot and it is not clear where exactly the data levels off. The ideal number of clusters could anywhere after 10.

# %% [markdown]
# #### Silhouette Score

# %%
from sklearn.metrics import silhouette_score

silhouette = []
for k in range(2, 25):
    km = KMeans(n_clusters = k, n_init = 50, random_state = 123)
    km.fit(data_scaled[['VALENCE','TEMPO']])
    silhouette.append(silhouette_score(data_scaled[['VALENCE','TEMPO']], km.labels_))

silhouette_series = pd.Series(silhouette, index = range(2, 25))

plt.figure(figsize = (8, 6))
ax = sns.lineplot(y = silhouette_series, x = silhouette_series.index)
ax = sns.scatterplot(y = silhouette_series, x = silhouette_series.index, s=150)
ax = ax.set(xlabel = 'Number of Clusters (k)', 
           ylabel = 'Average Silhouette Score')

# %% [markdown]
# Though there are several peaks, 20 appears to be the highest and therefore most ideal number of clusters. The elbow method also suggested that the ideal number of clusters could be between 15-25, so I will set k = 20.

# %% [markdown]
# ### 8. Results

# %%
# re-fit the model using the new k value.
km = KMeans(n_clusters = 20, n_init = 50, random_state = 123)
km.fit(data_scaled[["VALENCE", "TEMPO"]].copy())
# Out:
# KMeans(n_clusters=20, n_init=50, random_state=123)

# %%
# assign the songs to their new clusters
data_scaled["Cluster"] = km.labels_
data_scaled.head(50)
# Out:
#      VALENCE     TEMPO                TRACK_ID  \
# 0  -0.008065 -0.798407  2XU0oxnq2qxCpomAAuJY8K
# 1  -0.260115 -0.158388  696DnlkuDOXcMAnKlTgXXK
# 2   0.171971 -0.045252  21jGcNKet2qwijlDFuPiPb
# 3  -0.764216  1.698655  0sf12qNH5qcw8qpgymFOqD
# 4   0.266490 -0.693790  7k4t7uLgtOxPwTpFmtJNTY
# 5   0.270991 -1.038158  2b8fOow8UzyDFAE27YhOZM
# 6   0.572552 -0.150314  0nbXyq5TXYPCO7pr3N8S4I
# 7  -1.254815  0.195765  4TnjEaWOeW0eKTKIEvJyCa
# 8   0.730083  0.088137  6WrI0LAC5M1Rw2MnX2ZvEg
# 9  -1.223308 -0.046483  3ZCTVFBt2Brf31RLEnCkWJ
# 10  0.685074 -0.560059  6cy3ki60hLwimwIje7tALf
# 11 -0.089081  0.837359  41L3O37CECZt3N7ziG2z7l
# 12  0.212480  0.470856  2Fxmhks0bxGSBdJ92vM42m
# 13 -2.044723 -1.535929  3eekarcy7kvN4yt5ZFzltW
# 14  1.661770 -0.116890  2tnVG71enUj33Ic2nFN6kZ
# 15 -0.593182 -0.558280  3yOlyBJuViE2YSGn3nVE1K
# 16  0.734584  0.295045  7aiClxsDWFRQ0Kzk5KI5ku
# 17 -0.309625 -0.392528  7qEHsqek33rTcFNT9PFqLf
# 18 -0.030569  0.707220  5yY9lUy8nbvjM1Uyo1Uqoc
# 19 -1.904745 -0.662726  1HfMVBKM75vxSfsQ5VefZ5
# 20  1.445727  0.184920  6Ozh9Ok6h4Oi1wUSLtBseN
# 21  1.058649 -0.151135  0TK2YIli7K1leLovkQiNik
# 22  0.424022 -0.558930  2ksOAxtIxY8yElEWw8RhgK
# 23  0.050447 -1.005418  5DxXgozhkPLgrbKFY91w0c
# 24 -1.425849  1.662289  57vxBYXtHMk6H1aD29V7PU
# 25 -0.008065 -0.798407  5ZULALImTm80tzUbYQYM9d
# 26 -1.335831 -1.281604  285pBltuF7vW8TeWk8hdRR
# 27 -0.404144  2.007718  6Gg1gjgKi2AK4e0qzsR7sd
# 28  1.229684 -0.936038  6mAN61JH0dzyZpWslS11jy
# 29 -0.741712  0.228300  3VyjsVV24RmBIbWJAeUJNu
# 30 -0.084580  0.294464  51Fjme0JiitpyXKuyQiCDo
# 31 -0.984761  0.533873  2Ec33AVlkTTq8BHFgBTdQs
# 32 -0.773218  2.069503  5stPVcRqb4qixbafP9e8lt
# 33  0.243986 -0.763478  1M4qEo4HE3PRaCOM7EXNJq
# 34  0.063950  0.087932  7CHi4DtfK4heMlQaudCuHK
# 35 -0.386141  1.872174  0fea68AdmYNygeTGI4RC18
# 36  0.901118 -0.850887  6LcauUZjF1eXQrgqMUecHX
# 37  0.689575 -0.799810  4vUmTMuQqjdnvlZmAH61Qk
# 38 -0.381640 -1.073327  2wrJq5XKLnmhRXHIAf9xBa
# 39 -0.764216 -0.369401  6b2RcmUt1g9N9mQ3CbjX2Y
# 40 -1.218808  1.874910  2TH65lNHgvLxCKXM3apjxI
# 41 -1.493363 -0.324448  7ce20yLkzuXXLUhzIDoZih
# 42  1.472732 -0.663992  3HVWdVOQ0ZA45FuZGSfvns
# 43  0.725582 -1.142399  7sQKy5vlPQllr0k9IjYJv3
# 44 -0.075578  0.186049  1iQDltZqI7BXnHrFy4Qo1k
# 45  0.559049  0.502090  2YpeDb67231RjR0MgVLzsG
# 46  0.869611 -0.936894  6RyaV7owmVU6fzEPE17sF1
# 47 -0.845233  0.639174  6ocbgoVGwYJhOv1GgI9NsF
# 48 -1.299824  2.005083  1lOe9qE0vR9zwWQAOk6CoO
# 49  0.189975 -0.888622  1e9oZCCiX42nJl0AcqriVo
#
#                                            TRACK_NAME         TRACK_ARTIST  \
# 0                                        Dance Monkey          Tones and I
# 1                                             ROXANNE       Arizona Zervas
# 2                                             Circles          Post Malone
# 3                                     Blinding Lights           The Weeknd
# 4                                                Tusa              KAROL G
# 5                                            Memories             Maroon 5
# 6                                             The Box          Roddy Ricch
# 7                                             Falling        Trevor Daniel
# 8                                     Don't Start Now             Dua Lipa
# 9                                 everything i wanted        Billie Eilish
# 10                          RITMO (Bad Boys For Life)  The Black Eyed Peas
# 11                                              Yummy        Justin Bieber
# 12                                            bad guy        Billie Eilish
# 13                                HIGHEST IN THE ROOM         Travis Scott
# 14                                            Ride It               Regard
# 15                            My Oh My (feat. DaBaby)       Camila Cabello
# 16                                    hot girl bummer            blackbear
# 17                                  Someone You Loved        Lewis Capaldi
# 18                         Life Is Good (feat. Drake)               Future
# 19                                Lose You To Love Me         Selena Gomez
# 20                                                BOP               DaBaby
# 21                                           Señorita         Shawn Mendes
# 22                                              China             Anuel AA
# 23                                               Vete            Bad Bunny
# 24                                          Heartless           The Weeknd
# 25                                       Dance Monkey          Tones and I
# 26                                       Lucid Dreams           Juice WRLD
# 27           Bandit (with YoungBoy Never Broke Again)           Juice WRLD
# 28                                          Fantasias       Rauw Alejandro
# 29                                            No Idea          Don Toliver
# 30                                             Lalala                  Y2K
# 31                                Futsal Shuffle 2020         Lil Uzi Vert
# 32                                       Hola - Remix                Dalex
# 33                                          Adore You         Harry Styles
# 34                                       Lose Control               MEDUZA
# 35                                         LA CANCIÓN             J Balvin
# 36                                       Ayy Macarena                 Tyga
# 37  South of the Border (feat. Camila Cabello & Ca...           Ed Sheeran
# 38                  10,000 Hours (with Justin Bieber)           Dan + Shay
# 39                                  How Do You Sleep?            Sam Smith
# 40                                           Callaita            Bad Bunny
# 41                                      Before You Go        Lewis Capaldi
# 42                  I Don't Care (with Justin Bieber)           Ed Sheeran
# 43                                      Sigues Con El          Dimelo Flow
# 44                             Trampoline (with ZAYN)                SHAED
# 45                              Old Town Road - Remix            Lil Nas X
# 46                                  Que Tire Pa Lante         Daddy Yankee
# 47                                            7 rings        Ariana Grande
# 48                                             Ransom            Lil Tecca
# 49                                   Watermelon Sugar         Harry Styles
#
#     Cluster
# 0         8
# 1        12
# 2        12
# 3        10
# 4         8
# 5         8
# 6         9
# 7        18
# 8         9
# 9        18
# 10       17
# 11        2
# 12       12
# 13        7
# 14        0
# 15       19
# 16        9
# 17       19
# 18        2
# 19        7
# 20        0
# 21        9
# 22        8
# 23        8
# 24       15
# 25        8
# 26        7
# 27       10
# 28       13
# 29        1
# 30       12
# 31        6
# 32       10
# 33        8
# 34       12
# 35       10
# 36       17
# 37       17
# 38        5
# 39       19
# 40       15
# 41       18
# 42       13
# 43       17
# 44       12
# 45        9
# 46       17
# 47        6
# 48       15
# 49        8

# %%
cluster_centres = pd.DataFrame(km.cluster_centers_, columns = ['VALENCE','TEMPO'])

# %%
# set a colour palette for 20 colours
colours = ["#d3d3d3", "#2f4f4f", "#2e8b57", "#7f0000", "#808000", "#483d8b", "#ff0000", "#ff8c00", "#ffd700", "#0000cd", "#ba55d3", "#00ff7f", "#00bfff", "#adff2f", "#ff00ff", "#f0e68c", "#dda0dd", "#ff1493", "#ffa07a", "#7fffd4"]

# %%
# set fig size
plt.figure(figsize = (10, 8))

# plot clusters
ax = sns.scatterplot(data = data_scaled,
                    x = 'VALENCE',
                    y = 'TEMPO',
                    hue = 'Cluster',
                    palette = colours,
                    alpha = 0.8,
                    s = 150,
                    legend = False)

# plot centroids
ax = sns.scatterplot(data = cluster_centres,
                    x = 'VALENCE',
                    y = 'TEMPO',
                    hue = cluster_centres.index,
                    palette = colours,
                    s = 600,
                    marker = 'D',
                    ec = 'black',
                    legend = False)

# add centroid labels 
for i in range(len(cluster_centres)):
    plt.text(x = cluster_centres.VALENCE[i],
            y = cluster_centres.TEMPO[i],
            s = i,
            horizontalalignment = 'center',
            verticalalignment = 'center',
            size = 15,
            weight = 'bold',
            color = 'white')
